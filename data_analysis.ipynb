# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datasets/Air_Quality_20260405.csv')

# %%
df.head()
# Out:
#    Unique ID  Indicator ID                     Name Measure Measure Info  \
# 0     877071           375   Nitrogen dioxide (NO2)    Mean          ppb
# 1     877185           375   Nitrogen dioxide (NO2)    Mean          ppb
# 2     877080           375   Nitrogen dioxide (NO2)    Mean          ppb
# 3     876849           375   Nitrogen dioxide (NO2)    Mean          ppb
# 4     874599           365  Fine particles (PM 2.5)    Mean       mcg/m3
#
#   Geo Type Name  Geo Join ID                            Geo Place Name  \
# 0         UHF34       306308                           Chelsea-Village
# 1            CD          308  Crown Heights and Prospect Heights (CD8)
# 2         UHF34       501502                               Northern SI
# 3       Borough            2                                  Brooklyn
# 4            CD          204            Highbridge and Concourse (CD4)
#
#    Time Period  Start_Date  Data Value  Message
# 0  Summer 2023  06/01/2023   20.932670      NaN
# ...

# %%
df.info();
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18862 entries, 0 to 18861
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unique ID       18862 non-null  int64
#  1   Indicator ID    18862 non-null  int64
#  2   Name            18862 non-null  str
#  3   Measure         18862 non-null  str
#  4   Measure Info    18862 non-null  str
#  5   Geo Type Name   18862 non-null  str
#  6   Geo Join ID     18862 non-null  int64
#  7   Geo Place Name  18862 non-null  str
#  8   Time Period     18862 non-null  str
#  9   Start_Date      18862 non-null  str
#  10  Data Value      18862 non-null  float64
#  11  Message         0 non-null      float64
# dtypes: float64(2), int64(3), str(7)
# memory usage: 1.7 MB

# %% [markdown]
# No values in Message column

# %%
#drop Message column
df = df.drop(columns=['Message'])
df.info();
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18862 entries, 0 to 18861
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unique ID       18862 non-null  int64
#  1   Indicator ID    18862 non-null  int64
#  2   Name            18862 non-null  str
#  3   Measure         18862 non-null  str
#  4   Measure Info    18862 non-null  str
#  5   Geo Type Name   18862 non-null  str
#  6   Geo Join ID     18862 non-null  int64
#  7   Geo Place Name  18862 non-null  str
#  8   Time Period     18862 non-null  str
#  9   Start_Date      18862 non-null  str
#  10  Data Value      18862 non-null  float64
# dtypes: float64(1), int64(3), str(7)
# memory usage: 1.6 MB
