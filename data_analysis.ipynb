# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datasets/All_Statewide_Energy_Storage_Projects.csv')

# %%
df.info();
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7494 entries, 0 to 7493
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Data Through Date                  7494 non-null   str
#  1   Project ID                         7482 non-null   str
#  2   Interconnection Date               7494 non-null   str
#  3   Utility                            7494 non-null   str
#  4   City/Town                          7482 non-null   str
#  5   County                             7493 non-null   str
#  6   ZIP Code                           7494 non-null   int64
#  7   Division                           4377 non-null   str
#  8   Substation                         7454 non-null   str
#  9   Circuit ID                         7455 non-null   str
#  10  Storage Type                       7494 non-null   str
#  11  Developer                          7479 non-null   str
# ...

# %%
df.head()
# Out:
#   Data Through Date      Project ID Interconnection Date         Utility  \
# 0        12/31/2025       SDG-64828           02/07/2024          Con Ed
# 1        12/31/2025  PAM-2021-86262           03/01/2021          PSEGLI
# 2        12/31/2025     DGINT-11109           01/17/2022             O&R
# 3        12/31/2025     DGINT-07954           06/05/2019             O&R
# 4        12/31/2025        CH-15553           07/26/2022  Central Hudson
#
#     City/Town       County  ZIP Code  Division Substation Circuit ID  \
# 0         Rye  Westchester     10580    CENY-W   Harrison       51U4
# 1  West Islip      Suffolk     11795       NaN        270       2364
# 2     WARWICK       Orange     10990   CENTRAL     Wisner    80-5-13
# 3     WARWICK       Orange     10990   CENTRAL       Hunt    84-3-13
# 4      Beacon     Dutchess     12508  Fishkill   Tioronda       8087
#
#   Storage Type  Developer Metering Method  Energy Storage System Size (kWac)  \
# ...

# %%
df.isna().sum()
# Out:
# Data Through Date                       0
# Project ID                             12
# Interconnection Date                    0
# Utility                                 0
# City/Town                              12
# County                                  1
# ZIP Code                                0
# Division                             3117
# Substation                             40
# Circuit ID                             39
# Storage Type                            0
# Developer                              15
# Metering Method                       111
# Energy Storage System Size (kWac)       0
# Georeference                            0
# dtype: int64

# %%
df['Utility'].value_counts()
# Out:
# Utility
# PSEGLI            3105
# Central Hudson     968
# O&R                966
# Con Ed             882
# NYSEG              803
# National Grid      638
# RGE                131
# NYPA                 1
# Name: count, dtype: int64
